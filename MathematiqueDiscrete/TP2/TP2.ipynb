# %%
L = [2 ,3 ,5 ,7 ,11 ,13 ,42 ,0]
print(L)
# Out:
# [2, 3, 5, 7, 11, 13, 42, 0]

# %%
L [2:5]
# Out:
# [5, 7, 11]

# %%
[1..3 , 7 , 10..13]
# Out:
# [1, 2, 3, 7, 10, 11, 12, 13]

# %%
M=[7,"x",["pi","b"]]
print(M[2])
print(M[2][1])
# Out:
# ['pi', 'b']
# b

# %%
L = [2 ,3 ,5 ,7 ,11 ,13 ,42 ,0]
L[7] = 99
L
L.append("y")
print(L)
# Out:
# [2, 3, 5, 7, 11, 13, 42, 99, 'y']

# %%
N = [i^2 for i in range(1,6)]
print(N)
for i in range(0,len(N)) :
    N[i] = N[i]/(i+1)
print(N)
# Out:
# [1, 4, 9, 16, 25]
# [1, 2, 3, 4, 5]

# %%
[3,4,7]+[1,2]
# Out:
# [3, 4, 7, 1, 2]
